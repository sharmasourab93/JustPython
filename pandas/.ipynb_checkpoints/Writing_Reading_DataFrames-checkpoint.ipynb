# %% [markdown]
# # Pandas: Reading/Writing DataFrames From/To Files

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %% [markdown]
# ---

# %% [markdown]
# ### Filtering Dataframe to Select India Columns

# %%
filter_ = (df['Country'] == 'India')
india_df = df.loc[filter_]

# %%
india_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 7                     USD  ...                         NaN
# 22                    INR  ...                        Easy
# 58                    INR  ...  Neither easy nor difficult
# 63                    NaN  ...                        Easy
# 149                   INR  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 7                             NaN   NaN
# 22          Appropriate in length   NaN
# 58                       Too long   NaN
# 63          Appropriate in length    No
# 149         Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                        NaN
# 149         Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                    NaN
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                     NaN
# 149                                                    NaN
#
#                                                 WelcomeChange WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year         NaN
# 22                    Just as welcome now as I felt last year        50.0
# 58                                                        NaN         NaN
# 63          Not applicable - I did not use Stack Overflow ...         NaN
# 149                  Somewhat more welcome now than last year        70.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58               NaN          NaN
# 63                 4          NaN
# 149                5            3
#
# [5 rows x 60 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Writing to a CSV

# %%
india_df.to_csv('writing/modified.csv')

# %% [markdown]
# *Writing a Tab Separated File*

# %%
india_df.to_csv('writing/modified.tsv', sep='\t')

# %% [markdown]
# ---

# %% [markdown]
# ### Writing to an Excel

# %% [markdown]
# Before writing the Dataframe to an excel format, ensure the following packages are installed in your environment
# - xlwt
# - xlrd
# - openpyxl
#
# The section below will deal with writing files to excel and reading from them in order to test them out.

# %%
india_df.to_excel('writing/modified.xlsx')

# %% [markdown]
# *Testing the Data Frame Written to Excel*

# %%
testing_excel = pd.read_excel('writing/modified.xlsx', index_col='Respondent')

# %%
testing_excel.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58              NaN         NaN            NaN   India          Indian rupee
# 63              NaN         NaN            NaN   India                   NaN
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 7                     USD  ...                         NaN
# 22                    INR  ...                        Easy
# 58                    INR  ...  Neither easy nor difficult
# 63                    NaN  ...                        Easy
# 149                   INR  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 7                             NaN   NaN
# 22          Appropriate in length   NaN
# 58                       Too long   NaN
# 63          Appropriate in length    No
# 149         Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                        NaN
# 149         Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                    NaN
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                      NaN
# 22                                                     NaN
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                     NaN
# 149                                                    NaN
#
#                                                 WelcomeChange WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year         NaN
# 22                    Just as welcome now as I felt last year        50.0
# 58                                                        NaN         NaN
# 63          Not applicable - I did not use Stack Overflow ...         NaN
# 149                  Somewhat more welcome now than last year        70.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58               NaN          NaN
# 63                 4          NaN
# 149                5            3
#
# [5 rows x 60 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Writing To Json

# %% [markdown]
# The below section will deal with the following items:
# - Writing into JSON
# - Writing into JSON with Orientation as Lists/lines
# - Testing/Reading the written records

# %%
india_df.to_json('writing/modified.json')

# %%
india_df.to_json('writing/modified_orient.json', orient='records', lines=True)

# %%
test_json = pd.read_json('data/modified_orient.json', orient='records', lines=True)

# %%
test_json.head()
# Out:
#                                MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 0          I am a developer by profession      Yes   NaN         18  Monthly
# 1          I am a developer by profession      Yes   NaN         18  Monthly
# 2          I am a developer by profession      Yes   NaN         22     None
# 3  I am a student who is learning to code      Yes  21.0         17     None
# 4          I am a developer by profession      Yes  36.0         31   Yearly
#
#     CompTotal  ConvertedComp Country          CurrencyDesc CurrencySymbol  \
# 0         NaN            NaN   India  United States dollar            USD
# 1         NaN            NaN   India          Indian rupee            INR
# 2         NaN            NaN   India          Indian rupee            INR
# 3         NaN            NaN   India                  None           None
# 4  21000000.0       293196.0   India          Indian rupee            INR
#
#    ...                  SurveyEase           SurveyLength Trans  \
# 0  ...                        None                   None  None
# 1  ...                        Easy  Appropriate in length  None
# 2  ...  Neither easy nor difficult               Too long  None
# 3  ...                        Easy  Appropriate in length    No
# 4  ...  Neither easy nor difficult  Appropriate in length    No
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2                      Web development or web design
# 3                                               None
# 4  Computer science, computer engineering, or sof...
#
#                            WebframeDesireNextYear  \
# 0                                            None
# 1                                            None
# 2  Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3         Angular.js;Django;jQuery;Laravel;Vue.js
# 4                                            None
#
#                                WebframeWorkedWith  \
# 0                                            None
# 1                                            None
# 2  Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 3                                            None
# 4                                            None
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# 0              A lot more welcome now than last year         NaN         6
# 1            Just as welcome now as I felt last year        50.0        10
# 2                                               None         NaN      None
# 3  Not applicable - I did not use Stack Overflow ...         NaN         4
# 4           Somewhat more welcome now than last year        70.0         5
#
#   YearsCodePro
# 0            4
# 1            2
# 2         None
# 3         None
# 4            3
#
# [5 rows x 60 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Reading/Writing DataFrames From/To MySQL

# %% [markdown]
# The following actions are undertaken in order to learn working of Pandas Dataframe with SQL tables.
# - Creating Connection with the Database
# - Writing a table into MySQL table
# - Reading a table into Pandas Dataframe
# - Reading from a SQL Query

# %%
import sqlalchemy
import MySQLdb

# %%
sql = "mysql://"
user, pwd = "pacman", "pacman"
host = "192.168.1.103:3306"
db = "test"
conn = "{0}{1}:{2}@{3}/{4}".format(sql, user, pwd, host, db)

# %%
conn
# Out:
# 'mysql://pacman:pacman@192.168.1.103:3306/test'

# %% [markdown]
# ##### Writing a Dataframe Into SQL

# %%
india_df.to_sql(con=conn, name='india_df', if_exists='replace')

# %% [markdown]
# ![maria_db.JPG](attachment:maria_db.JPG)

# %% [markdown]
# Displaying count of the df written to SQL Table

# %%
india_df.shape
# Out:
# (8403, 60)

# %% [markdown]
# ![maria_db_count.JPG](attachment:maria_db_count.JPG)

# %% [markdown]
# ##### Reading a Dataframe From SQL

# %%
sql_df = pd.read_sql('india_df', con=conn, index_col='Respondent')

# %%
sql_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
#
#            CompFreq   CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 7           Monthly         NaN            NaN   India  United States dollar
# 22          Monthly         NaN            NaN   India          Indian rupee
# 58             None         NaN            NaN   India          Indian rupee
# 63             None         NaN            NaN   India                  None
# 149          Yearly  21000000.0       293196.0   India          Indian rupee
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 7                     USD  ...                        None
# 22                    INR  ...                        Easy
# 58                    INR  ...  Neither easy nor difficult
# 63                   None  ...                        Easy
# 149                   INR  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 7                            None  None
# 22          Appropriate in length  None
# 58                       Too long  None
# 63          Appropriate in length    No
# 149         Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 22          Computer science, computer engineering, or sof...
# 58                              Web development or web design
# 63                                                       None
# 149         Computer science, computer engineering, or sof...
#
#                                     WebframeDesireNextYear  \
# Respondent
# 7                                                     None
# 22                                                    None
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                 Angular.js;Django;jQuery;Laravel;Vue.js
# 149                                                   None
#
#                                         WebframeWorkedWith  \
# Respondent
# 7                                                     None
# 22                                                    None
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 63                                                    None
# 149                                                   None
#
#                                                 WelcomeChange WorkWeekHrs  \
# Respondent
# 7                       A lot more welcome now than last year         NaN
# 22                    Just as welcome now as I felt last year        50.0
# 58                                                       None         NaN
# 63          Not applicable - I did not use Stack Overflow ...         NaN
# 149                  Somewhat more welcome now than last year        70.0
#
#            YearsCode YearsCodePro
# Respondent
# 7                  6            4
# 22                10            2
# 58              None         None
# 63                 4         None
# 149                5            3
#
# [5 rows x 60 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Writing Raw SQL Queries to Write Dataframe

# %%
sql_query = pd.read_sql_query('select * from india_df where Age=36', con=conn, index_col='Respondent')

# %%
sql_query.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 149                            I am a developer by profession      Yes  36.0
# 1893                           I am a developer by profession      Yes  36.0
# 6347                           I am a developer by profession      Yes  36.0
# 6464                           I am a developer by profession       No  36.0
# 6997        I used to be a developer by profession, but no...       No  36.0
#
#            Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# Respondent
# 149                31   Yearly  21000000.0       293196.0   India
# 1893               13     None         NaN            NaN   India
# 6347               23  Monthly   2500000.0       418848.0   India
# 6464               17   Yearly   1857000.0        25927.0   India
# 6997               18     None         NaN            NaN   India
#
#             CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# Respondent                               ...
# 149         Indian rupee            INR  ...  Neither easy nor difficult
# 1893        Indian rupee            INR  ...                        Easy
# 6347        Indian rupee            INR  ...                        Easy
# 6464        Indian rupee            INR  ...                        Easy
# 6997                None           None  ...                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 149         Appropriate in length    No
# 1893        Appropriate in length    No
# 6347                     Too long    No
# 6464        Appropriate in length    No
# 6997                     Too long    No
#
#                                                UndergradMajor  \
# Respondent
# 149         Computer science, computer engineering, or sof...
# 1893        Computer science, computer engineering, or sof...
# 6347        Computer science, computer engineering, or sof...
# 6464        Another engineering discipline (such as civil,...
# 6997        Another engineering discipline (such as civil,...
#
#                     WebframeDesireNextYear        WebframeWorkedWith  \
# Respondent
# 149                                   None                      None
# 1893          ASP.NET Core;Gatsby;React.js     ASP.NET Core;React.js
# 6347                                  None                    Django
# 6464        Angular;jQuery;React.js;Spring  Angular.js;jQuery;Spring
# 6997                              React.js                      None
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 149         Somewhat more welcome now than last year        70.0         5
# 1893         Just as welcome now as I felt last year        56.0        17
# 6347        Somewhat more welcome now than last year        40.0        11
# 6464         Just as welcome now as I felt last year        40.0        18
# 6997         Just as welcome now as I felt last year         NaN         2
#
#                 YearsCodePro
# Respondent
# 149                        3
# 1893                      11
# 6347                      11
# 6464                      13
# 6997        Less than 1 year
#
# [5 rows x 60 columns]
